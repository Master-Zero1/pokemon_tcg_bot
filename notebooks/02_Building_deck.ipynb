# %%
import sys
sys.path.append(r"C:\Users\prith\Downloads\Project - ml\Pokemon TCG Bot\pokemon_tcg_bot")

import pandas as pd

# %%
from cg.api import all_card_data

# %%
all_cards = all_card_data()

# %%
for c in all_cards:
    print(c.cardId, c.name)
# Out:
# 1 Basic {G} Energy
# 2 Basic {R} Energy
# 3 Basic {W} Energy
# 4 Basic {L} Energy
# 5 Basic {P} Energy
# 6 Basic {F} Energy
# 7 Basic {D} Energy
# 8 Basic {M} Energy
# 9 Boomerang Energy
# 10 Neo Upper Energy
# 11 Mist Energy
# 12 Legacy Energy
# 13 Enriching Energy
# 14 Spiky Energy
# 15 Team Rocket's Energy
# 16 Prism Energy
# 17 Ignition Energy
# 18 Grow Grass Energy
# 19 Telepath Psychic Energy
# 20 Rock Fighting Energy
# 21 Scrafty
# 22 Hippopotas
# 23 Hippowdon
# 24 Team Rocket's Kangaskhan ex
# 25 Pinsir
# 26 Leafeon
# 27 Iron Leaves
# 28 Poltchageist
# 29 Sinistcha ex
# 30 Magcargo ex
# 31 Chi-Yu
# 32 Glaceon
# 33 Froakie
# 34 Frogadier
# 35 Walking Wake
# 36 Morpeko
# 37 Iron Thorns ex
# 38 Girafarig
# 39 Enamorus
# 40 Greninja ex
# 41 Ting-Lu
# 42 Applin
# 43 Eevee
# 44 Bloodmoon Ursaluna ex
# 45 Shaymin
# 46 Gouging Fire ex
# 47 Totodile
# 48 Croconaw
# 49 Feraligatr
# 50 Wiglett
# 51 Palafin
# 52 Wugtrio ex
# 53 Marill
# 54 Bronzor
# 55 Bronzong
# 56 Flutter Mane
# ...

# %%
deck = []

#Pokemons
deck += [119]*4 #Dreepy
deck += [120]*4 #Drakloak
deck += [121]*3 #Dragapult ex
deck += [131]*2 #Duskull
deck += [132]*2 #Dusclops
deck += [133]*1 #Dusknoir
deck += [235]*2 #Budew
deck += [44]*1 #Bloodmoon Ursaluna ex
deck += [140]*1 #Fezandipiti ex
deck += [184]*1 #Latias ex
deck += [112]*1 # Munkidori
deck += [1055]*1 #Hawlucha

#Supporters
deck += [1227]*4 #Lillie's Determination
deck += [1182]*3 #Boss's Orders
deck += [1190]*1 #Bianca's Devotion
deck += [1213]*3 #Judge
deck += [1225]*1 #Hilda
deck += [1237]*1 #Lucian

#Items
deck += [1086]*4 #Buddy-Buddy Poffin
deck += [1097]*2 #Night Stretcher
deck += [1123]*1 #Switch
deck += [1152]*4 #Poké Pad
deck += [1121]*1 #Ultra Ball
deck += [1081]*1 #Enhanced Hammer
deck += [1120]*3 #Crushing Hammer
deck += [1080]*1 #Unfair Stamp

#Energy
deck += [5]*7 #Basic Psychic Energy

deck_df = pd.DataFrame(deck)

deck_df.to_csv(r"C:\Users\prith\Downloads\Project - ml\Pokemon TCG Bot\pokemon_tcg_bot\data\deck.csv", index=False, header=False)
